# %% [markdown]
# <a href="https://colab.research.google.com/github/avantikabijalwan19-ux/Numerical-Analysis/blob/main/jacobi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def jacobi():
    n = int(input("Enter number of equations: "))
    A = []
    b = []
    for i in range(n):
        row = list(map(float, input(f"Enter row {i+1} coefficients: ").split()))
        A.append(row)
        b.append(float(input(f"Enter b{i+1}: ")))

    x = [0.0] * n
    for k in range(100):
        x_new = [0.0] * n
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        if max(abs(x_new[i] - x[i]) for i in range(n)) < 0.0001:
            break
        x = x_new

    for i in range(n):
        print(f"x{i+1} =", format(x[i], ".4f"))

jacobi()
# Out:
# Enter number of equations: 3
# Enter row 1 coefficients: 4 1 -1
# Enter b1: 3
# Enter row 2 coefficients: 2 7 1
# Enter b2: 19
# Enter row 3 coefficients: 1 -3 12
# Enter b3: 31
# x1 = 1.0000
# x2 = 2.0000
# x3 = 3.0000
